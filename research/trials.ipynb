# %%
#config box

d = {"key1": "value" , "key2": "value2"}

# %%
d['key1']
# Out:
# 'value'

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
d1 = ConfigBox({"key1": "value" , "key2": "value2"})

# %%
d1.key1
# Out:
# 'value'

# %%
d1.key2
# Out:
# 'value2'

# %%
type(d1)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict
